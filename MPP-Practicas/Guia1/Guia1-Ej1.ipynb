# %%
import numpy as np

# %%
dim = 5

v = np.random.rand(dim)

# %%
print(v)
# Out:
# [0.18717883 0.99146033 0.23786151 0.27543399 0.14677749]

# %%
np.sort(v)
# Out:
# array([0.14677749, 0.18717883, 0.23786151, 0.27543399, 0.99146033])

# %%
np.save('test.npy',v)

# %% [markdown]
# # EJ2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math

# %%
def funexp (x,n):

    y = 1

    for i in range(1,n):
        y += (x**i)/math.factorial(i)
        print(y)

    return y

# %%
funexp(0.5,10)
# Out:
# 1.5
# 1.625
# 1.6458333333333333
# 1.6484375
# 1.6486979166666667
# 1.6487196180555554
# 1.6487211681547618
# 1.6487212650359622
# 1.648721270418251
# 1.648721270418251
